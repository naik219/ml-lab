# %%
import pandas as pd
import numpy as np 
import os
import kagglehub
path = kagglehub.dataset_download("uciml/iris")
print("Dataset path:", path)
print("Files:" , os.listdir(path))
# Out:
# Dataset path: C:\Users\CSE Lab\.cache\kagglehub\datasets\uciml\iris\versions\2
# Files: ['database.sqlite', 'Iris.csv']

# %%
file_path = os.path.join(path,"Iris.csv")
df = pd.read_csv(file_path)
print("---original raw data sample---")
print(df.to_string())
# Out:
# ---original raw data sample---
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm          Species
# 0      1            5.1           3.5            1.4           0.2      Iris-setosa
# 1      2            4.9           3.0            1.4           0.2      Iris-setosa
# 2      3            4.7           3.2            1.3           0.2      Iris-setosa
# 3      4            4.6           3.1            1.5           0.2      Iris-setosa
# 4      5            5.0           3.6            1.4           0.2      Iris-setosa
# 5      6            5.4           3.9            1.7           0.4      Iris-setosa
# 6      7            4.6           3.4            1.4           0.3      Iris-setosa
# 7      8            5.0           3.4            1.5           0.2      Iris-setosa
# 8      9            4.4           2.9            1.4           0.2      Iris-setosa
# 9     10            4.9           3.1            1.5           0.1      Iris-setosa
# ...

# %%
df_binary=df[df["Species"].isin(["Iris-setosa","Iris-versicolor"])]
X = df_binary
